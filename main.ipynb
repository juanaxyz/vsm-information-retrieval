# %% [markdown]
# # Prerequisites

# %%
import re
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
import math
import pandas as pd
from collections import Counter

# %%
stemmer = StemmerFactory().create_stemmer()
stopword_factory = StopWordRemoverFactory()
stopwords = set(stopword_factory.get_stop_words())
print(stopwords)
# Out:
# {'atau', 'dari', 'saya', 'apalagi', 'ok', 'menurut', 'kepada', 'pada', 'kita', 'dapat', 'sebagai', 'agar', 'kenapa', 'jika', 'ingin', 'kemana', 'oh', 'sesuatu', 'bisa', 'ya', 'harus', 'lagi', 'tentu', 'nggak', 'dahulu', 'tentang', 'selain', 'seharusnya', 'agak', 'tapi', 'itulah', 'toh', 'kembali', 'setidaknya', 'maka', 'mereka', 'secara', 'sehingga', 'anu', 'ketika', 'pula', 'setiap', 'oleh', 'sedangkan', 'anda', 'terhadap', 'dimana', 'seterusnya', 'dst', 'sebelum', 'dsb', 'sesudah', 'di', 'yakni', 'seolah', 'walau', 'itu', 'sampai', 'para', 'nanti', 'sambil', 'tetapi', 'juga', 'bagi', 'saja', 'tolong', 'pasti', 'ia', 'yang', 'namun', 'dengan', 'dalam', 'serta', 'dll', 'untuk', 'dia', 'pun', 'amat', 'adalah', 'mengapa', 'mari', 'apakah', 'karena', 'sekitar', 'demikian', 'saat', 'daripada', 'telah', 'setelah', 'bahwa', 'begitu', 'ke', 'dulunya', 'kami', 'akan', 'dan', 'kah', 'demi', 'hanya', 'seperti', 'masih', 'lain', 'tanpa', 'hal', 'sebetulnya', 'bagaimanapun', 'guna', 'sementara', 'seraya', 'yaitu', 'dua', 'ini', 'belum', 'selagi', 'ada', 'sudah', 'boleh', 'supaya', 'kecuali', 'sebab', 'melainkan', 'antara', 'tidak'}

# %% [markdown]
# # Fungsi untuk preprocessing

# %%
def tokenize(text):
    # Menghapus karakter non-alphanumeric
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    # Mengubah teks menjadi huruf kecil dan memisahkan kata-kata
    tokens = text.lower().split()
    return tokens

# Contoh penggunaan
tokens = tokenize("Ini adalah contoh kalimat untuk tokenisasi!")
print("Tokens setelah tokenisasi:", tokens)
# Out:
# Tokens setelah tokenisasi: ['ini', 'adalah', 'contoh', 'kalimat', 'untuk', 'tokenisasi']

# %%
def remove_stopwords(tokens):
    return [word for word in tokens if word not in stopwords]


tokens_no_stopwords = remove_stopwords(tokens)
print("Setelah menghapus stopwords:", tokens_no_stopwords)
# Out:
# Setelah menghapus stopwords: ['contoh', 'kalimat', 'tokenisasi']

# %%
def stemming(tokens):
    return [stemmer.stem(word) for word in tokens]

# %%
def preprocess(sentence):
    tokens = tokenize(sentence)
    tokens_no_stopwords = remove_stopwords(tokens)
    stemmed_tokens = stemming(tokens_no_stopwords)
    return stemmed_tokens

# %% [markdown]
# # Preprocess data

# %% [markdown]
# ## Menentukan Query dan Docs

# %%
query = "strategi pemasaran digital untuk UMKM"

docs = [
    "pelatihan kewirausahaan membantu pelaku usaha kecil memahami manajemen keuangan dasar",
    "tim pemasaran menyusun kampanye media sosial untuk meningkatkan penjualan produk lokal",
    "petani kopi di daerah pegunungan mulai menggunakan aplikasi cuaca untuk menentukan jadwal panen",
    "rumah sakit daerah menambah layanan konsultasi kesehatan secara daring bagi pasien lansia",
    "pengembangan aplikasi mobile membutuhkan pengujian antarmuka agar pengalaman pengguna tetap baik",
    "wisata bahari di indonesia timur menarik minat turis karena keindahan terumbu karang",
    "umkm kuliner memanfaatkan platform marketplace untuk memperluas jangkauan pelanggan",
    "kelas data science membahas regresi linear klasifikasi dan evaluasi model prediksi",
    "dinas perhubungan menguji sistem pembayaran nontunai pada transportasi umum di kota besar",
    "strategi konten video pendek efektif untuk membangun brand awareness di kalangan anak muda",
    "penelitian energi terbarukan fokus pada efisiensi panel surya dan penyimpanan baterai",
    "program literasi digital mengajarkan keamanan akun dan perlindungan data pribadi",
    "komunitas sepeda rutin mengadakan kegiatan akhir pekan untuk kampanye gaya hidup sehat",
    "analisis perilaku konsumen membantu bisnis menentukan harga promosi yang lebih tepat",
    "usaha kerajinan tangan meningkatkan omzet setelah menerapkan iklan digital bertarget"
]

# %%
query = "penerapan kecerdasan buatan dalam pendidikan"

docs = [
    "kecerdasan buatan digunakan untuk membantu proses pembelajaran adaptif di sekolah",
    "guru memanfaatkan teknologi digital untuk membuat materi pembelajaran lebih menarik",
    "penggunaan ai dalam pendidikan membantu analisis kemampuan siswa secara otomatis",
    "perpustakaan digital menyediakan akses buku bagi mahasiswa",
    "sistem pembelajaran online semakin berkembang sejak pandemi",
]

# %%
query = "pola hidup sehat untuk menjaga jantung"

docs = [
    "olahraga rutin dapat meningkatkan kesehatan jantung dan stamina tubuh",
    "konsumsi makanan berlemak berlebihan dapat menyebabkan penyakit jantung",
    "tidur yang cukup membantu menjaga kesehatan tubuh secara keseluruhan",
    "rumah sakit menyediakan layanan pemeriksaan jantung secara berkala",
    "minum air putih yang cukup penting untuk metabolisme tubuh",
]

# %%
query = "tips belajar efektif untuk mahasiswa"

docs = [
    "manajemen waktu membantu mahasiswa menyelesaikan tugas tepat waktu",
    "belajar secara konsisten lebih efektif dibanding sistem kebut semalam",
    "diskusi kelompok dapat meningkatkan pemahaman materi kuliah",
    "mahasiswa perlu menjaga kesehatan mental selama perkuliahan",
    "metode mencatat yang baik membantu mengingat materi lebih lama",
]

# %%
query = "strategi menang dalam game battle royale"

docs = [
    "pemain harus mengatur posisi dan strategi bertahan di zona aman",
    "loot senjata yang tepat sangat penting untuk bertahan hidup",
    "komunikasi tim membantu koordinasi dalam permainan battle royale",
    "grafik game yang realistis meningkatkan pengalaman bermain",
    "latihan aim meningkatkan kemampuan menembak pemain",
]

# %% [markdown]
# ## Preprocess Docs dan Query

# %%
print("Raw Data:")
for i, doc in enumerate(docs):
    print(f"Dokumen {i+1}: {doc}")
    
print("=" * 50)
preprocessed_docs = [preprocess(doc) for doc in docs]
print("Dokumen setelah preprocessing:")
for i, doc in enumerate(preprocessed_docs):
    print(f"Dokumen {i+1}: {doc}")
    
print("=" * 50)
print("raw query:", query)
query_preprocessed = preprocess(query)
print("Query setelah preprocessing:", query_preprocessed)
# Out:
# Raw Data:
# Dokumen 1: olahraga rutin dapat meningkatkan kesehatan jantung dan stamina tubuh
# Dokumen 2: konsumsi makanan berlemak berlebihan dapat menyebabkan penyakit jantung
# Dokumen 3: tidur yang cukup membantu menjaga kesehatan tubuh secara keseluruhan
# Dokumen 4: rumah sakit menyediakan layanan pemeriksaan jantung secara berkala
# Dokumen 5: minum air putih yang cukup penting untuk metabolisme tubuh
# ==================================================
# Dokumen setelah preprocessing:
# Dokumen 1: ['olahraga', 'rutin', 'tingkat', 'sehat', 'jantung', 'stamina', 'tubuh']
# Dokumen 2: ['konsumsi', 'makan', 'lemak', 'lebih', 'sebab', 'sakit', 'jantung']
# Dokumen 3: ['tidur', 'cukup', 'bantu', 'jaga', 'sehat', 'tubuh', 'seluruh']
# Dokumen 4: ['rumah', 'sakit', 'sedia', 'layan', 'periksa', 'jantung', 'kala']
# Dokumen 5: ['minum', 'air', 'putih', 'cukup', 'penting', 'metabolisme', 'tubuh']
# ==================================================
# raw query: pola hidup sehat untuk menjaga jantung
# Query setelah preprocessing: ['pola', 'hidup', 'sehat', 'jaga', 'jantung']

# %%
N = len(docs)
all_term = query_preprocessed + [term for doc in preprocessed_docs for term in doc]
term = sorted(list(set(all_term)))
print("panjang Docs:", N)
print(term)
# Out:
# panjang Docs: 5
# ['air', 'bantu', 'cukup', 'hidup', 'jaga', 'jantung', 'kala', 'konsumsi', 'layan', 'lebih', 'lemak', 'makan', 'metabolisme', 'minum', 'olahraga', 'penting', 'periksa', 'pola', 'putih', 'rumah', 'rutin', 'sakit', 'sebab', 'sedia', 'sehat', 'seluruh', 'stamina', 'tidur', 'tingkat', 'tubuh']

# %% [markdown]
# # Fungsi Hitung TF - IDF, Weight

# %%
def hitung_tf(doc):
    # TF mentah (jumlah kemunculan term dalam 1 dokumen)
    freq = Counter(doc)
    return {t: freq.get(t, 0) for t in term}

def hitung_df_per_term(t, docs_list):
    # DF = jumlah dokumen yang mengandung term t (bukan jumlah frekuensi)
    return sum(1 for d in docs_list if t in d)

# %%
# DataFrame dokumen asli vs hasil preprocessing
df_docs = pd.DataFrame({
    "dokumen_asli": docs,
    "dokumen_preprocessed": [" ".join(doc) for doc in preprocessed_docs]
})

# DataFrame TF dibalik: kolom = dokumen, baris = term
df_tf = pd.DataFrame(
    [hitung_tf(doc) for doc in preprocessed_docs],
    index=[f"D{i+1}" for i in range(N)]
).T

# Tambah kolom TF untuk query
df_tf["Q"] = pd.Series(hitung_tf(query_preprocessed))



df=df_tf.copy()
df["DF"]=[hitung_df_per_term(t, preprocessed_docs) for t in df.index]


tf_idf = df.copy()
tf_idf["IDF (log N/df)"] = tf_idf["DF"].apply(lambda df: math.log(N / df) + 1 if df > 0 else 0)


def hitung_weight(tf, idf):
    return tf * idf

# Hitung bobot (W) untuk semua dokumen D1..D7
columns=[f"D{i+1}" for i in range(N)]
for col in columns:  # columns = ['D1', ..., 'D7']
    tf_idf[f"W_{col}"] = tf_idf.apply(
        lambda row: hitung_weight(row[col], row["IDF (log N/df)"]),
        axis=1
    )

# Jika ingin juga bobot query, aktifkan baris ini:
tf_idf["W_Q"] = tf_idf.apply(lambda row: hitung_weight(row["Q"], row["IDF (log N/df)"]), axis=1)

# %% [markdown]
# ## visualisasi table

# %%
print(f"query :", query_preprocessed)
# print("TF:")
# display(df_tf)


# print("DF:")
# display(df)

print("TF-IDF:")
display(tf_idf)
# Out:
# query : ['pola', 'hidup', 'sehat', 'jaga', 'jantung']
# TF-IDF:
#              D1  D2  D3  D4  D5  Q  DF  IDF (log N/df)      W_D1      W_D2  \
# air           0   0   0   0   1  0   1        2.609438  0.000000  0.000000
# bantu         0   0   1   0   0  0   1        2.609438  0.000000  0.000000
# cukup         0   0   1   0   1  0   2        1.916291  0.000000  0.000000
# hidup         0   0   0   0   0  1   0        0.000000  0.000000  0.000000
# jaga          0   0   1   0   0  1   1        2.609438  0.000000  0.000000
# jantung       1   1   0   1   0  1   3        1.510826  1.510826  1.510826
# kala          0   0   0   1   0  0   1        2.609438  0.000000  0.000000
# konsumsi      0   1   0   0   0  0   1        2.609438  0.000000  2.609438
# layan         0   0   0   1   0  0   1        2.609438  0.000000  0.000000
# lebih         0   1   0   0   0  0   1        2.609438  0.000000  2.609438
# lemak         0   1   0   0   0  0   1        2.609438  0.000000  2.609438
# makan         0   1   0   0   0  0   1        2.609438  0.000000  2.609438
# metabolisme   0   0   0   0   1  0   1        2.609438  0.000000  0.000000
# minum         0   0   0   0   1  0   1        2.609438  0.000000  0.000000
# olahraga      1   0   0   0   0  0   1        2.609438  2.609438  0.000000
# penting       0   0   0   0   1  0   1        2.609438  0.000000  0.000000
# periksa       0   0   0   1   0  0   1        2.609438  0.000000  0.000000
# pola          0   0   0   0   0  1   0        0.000000  0.000000  0.000000
# putih         0   0   0   0   1  0   1        2.609438  0.000000  0.000000
# rumah         0   0   0   1   0  0   1        2.609438  0.000000  0.000000
# rutin         1   0   0   0   0  0   1        2.609438  2.609438  0.000000
# sakit         0   1   0   1   0  0   2        1.916291  0.000000  1.916291
# sebab         0   1   0   0   0  0   1        2.609438  0.000000  2.609438
# sedia         0   0   0   1   0  0   1        2.609438  0.000000  0.000000
# sehat         1   0   1   0   0  1   2        1.916291  1.916291  0.000000
# seluruh       0   0   1   0   0  0   1        2.609438  0.000000  0.000000
# stamina       1   0   0   0   0  0   1        2.609438  2.609438  0.000000
# tidur         0   0   1   0   0  0   1        2.609438  0.000000  0.000000
# tingkat       1   0   0   0   0  0   1        2.609438  2.609438  0.000000
# tubuh         1   0   1   0   1  0   3        1.510826  1.510826  0.000000
#
#                  W_D3      W_D4      W_D5       W_Q
# air          0.000000  0.000000  2.609438  0.000000
# bantu        2.609438  0.000000  0.000000  0.000000
# cukup        1.916291  0.000000  1.916291  0.000000
# hidup        0.000000  0.000000  0.000000  0.000000
# jaga         2.609438  0.000000  0.000000  2.609438
# jantung      0.000000  1.510826  0.000000  1.510826
# kala         0.000000  2.609438  0.000000  0.000000
# konsumsi     0.000000  0.000000  0.000000  0.000000
# layan        0.000000  2.609438  0.000000  0.000000
# lebih        0.000000  0.000000  0.000000  0.000000
# lemak        0.000000  0.000000  0.000000  0.000000
# makan        0.000000  0.000000  0.000000  0.000000
# metabolisme  0.000000  0.000000  2.609438  0.000000
# minum        0.000000  0.000000  2.609438  0.000000
# olahraga     0.000000  0.000000  0.000000  0.000000
# penting      0.000000  0.000000  2.609438  0.000000
# periksa      0.000000  2.609438  0.000000  0.000000
# pola         0.000000  0.000000  0.000000  0.000000
# putih        0.000000  0.000000  2.609438  0.000000
# rumah        0.000000  2.609438  0.000000  0.000000
# rutin        0.000000  0.000000  0.000000  0.000000
# sakit        0.000000  1.916291  0.000000  0.000000
# sebab        0.000000  0.000000  0.000000  0.000000
# sedia        0.000000  2.609438  0.000000  0.000000
# sehat        1.916291  0.000000  0.000000  1.916291
# seluruh      2.609438  0.000000  0.000000  0.000000
# stamina      0.000000  0.000000  0.000000  0.000000
# tidur        2.609438  0.000000  0.000000  0.000000
# tingkat      0.000000  0.000000  0.000000  0.000000
# tubuh        1.510826  0.000000  1.510826  0.000000

# %% [markdown]
# ## Hitung Jarak tiap dokumen dan query

# %%
# Hitung jumlah kuadrat dan akar (norm) untuk query dan tiap dokumen
sum_sq = {col: float((tf_idf[f"W_{col}"] ** 2).sum()) for col in columns + ["Q"]}
norm = {col: math.sqrt(val) for col, val in sum_sq.items()}

jarak_df = pd.DataFrame({
    "sum_pangkat_2": sum_sq,
    "akar": norm
}).T
print("Norm vektor (|D| dan |Q|):")
display(jarak_df)
# Out:
# Norm vektor (|D| dan |Q|):
#                       D1         D2         D3         D4         D5  \
# sum_pangkat_2  35.474023  40.000595  36.863599  40.000595  40.000595
# akar            5.956007   6.324602   6.071540   6.324602   6.324602
#
#                        Q
# sum_pangkat_2  12.763930
# akar            3.572664

# %% [markdown]
# ## Keterangan Komponen Cosine Similarity
#
# - **Sum(Q × D)**: jumlah hasil perkalian bobot query dan bobot dokumen pada setiap term.
# - **|Q|**: panjang (norma) vektor query.
# - **|D|**: panjang (norma) vektor dokumen.
#
# \[
# \cos(Q, D)=\frac{\sum (Q_i \times D_i)}{|Q| \times |D|}
# \]

# %% [markdown]
# # Menghitung Cosine Similarity untuk SVM

# %%
# Tabel detail seperti perhitungan manual: Q^2, D_i^2, dan Q*D_i
detail = pd.DataFrame(index=tf_idf.index)
detail["Q^2"] = tf_idf["W_Q"] ** 2

for d in columns:
    detail[f"{d}^2"] = tf_idf[f"W_{d}"] ** 2
    detail[f"Q*{d}"] = tf_idf["W_Q"] * tf_idf[f"W_{d}"]

print("Tabel detail cosine (per term):")
display(detail.round(6))

# Rekap sum dan cosine similarity per dokumen
sum_q2 = float(detail["Q^2"].sum())
sqrt_q = math.sqrt(sum_q2)

hasil = []
for d in columns:
    sum_d2 = float(detail[f"{d}^2"].sum())
    sqrt_d = math.sqrt(sum_d2)
    sum_qd = float(detail[f"Q*{d}"].sum())
    cosine = sum_qd / (sqrt_q * sqrt_d) if sqrt_q > 0 and sqrt_d > 0 else 0.0
    hasil.append({
        "dokumen": d,
        "Sum(Q*D)": sum_qd,
        "|Q|": sqrt_q,
        "|D|": sqrt_d,
        "cosine_similarity": cosine
    })

df_cosine = pd.DataFrame(hasil).sort_values("cosine_similarity", ascending=False)

print("Ranking cosine similarity:")
display(df_cosine.round(6))
# Out:
# Tabel detail cosine (per term):
#                   Q^2      D1^2      Q*D1      D2^2      Q*D2      D3^2  \
# air          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# bantu        0.000000  0.000000  0.000000  0.000000  0.000000  6.809166
# cukup        0.000000  0.000000  0.000000  0.000000  0.000000  3.672170
# hidup        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# jaga         6.809166  0.000000  0.000000  0.000000  0.000000  6.809166
# jantung      2.282594  2.282594  2.282594  2.282594  2.282594  0.000000
# kala         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# konsumsi     0.000000  0.000000  0.000000  6.809166  0.000000  0.000000
# layan        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# lebih        0.000000  0.000000  0.000000  6.809166  0.000000  0.000000
# lemak        0.000000  0.000000  0.000000  6.809166  0.000000  0.000000
# makan        0.000000  0.000000  0.000000  6.809166  0.000000  0.000000
# metabolisme  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# minum        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# olahraga     0.000000  6.809166  0.000000  0.000000  0.000000  0.000000
# penting      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# periksa      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# pola         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# putih        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# rumah        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# rutin        0.000000  6.809166  0.000000  0.000000  0.000000  0.000000
# sakit        0.000000  0.000000  0.000000  3.672170  0.000000  0.000000
# sebab        0.000000  0.000000  0.000000  6.809166  0.000000  0.000000
# sedia        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# sehat        3.672170  3.672170  3.672170  0.000000  0.000000  3.672170
# seluruh      0.000000  0.000000  0.000000  0.000000  0.000000  6.809166
# stamina      0.000000  6.809166  0.000000  0.000000  0.000000  0.000000
# tidur        0.000000  0.000000  0.000000  0.000000  0.000000  6.809166
# tingkat      0.000000  6.809166  0.000000  0.000000  0.000000  0.000000
# tubuh        0.000000  2.282594  0.000000  0.000000  0.000000  2.282594
#
#                  Q*D3      D4^2      Q*D4      D5^2  Q*D5
# air          0.000000  0.000000  0.000000  6.809166   0.0
# bantu        0.000000  0.000000  0.000000  0.000000   0.0
# cukup        0.000000  0.000000  0.000000  3.672170   0.0
# hidup        0.000000  0.000000  0.000000  0.000000   0.0
# jaga         6.809166  0.000000  0.000000  0.000000   0.0
# jantung      0.000000  2.282594  2.282594  0.000000   0.0
# kala         0.000000  6.809166  0.000000  0.000000   0.0
# konsumsi     0.000000  0.000000  0.000000  0.000000   0.0
# layan        0.000000  6.809166  0.000000  0.000000   0.0
# lebih        0.000000  0.000000  0.000000  0.000000   0.0
# lemak        0.000000  0.000000  0.000000  0.000000   0.0
# makan        0.000000  0.000000  0.000000  0.000000   0.0
# metabolisme  0.000000  0.000000  0.000000  6.809166   0.0
# minum        0.000000  0.000000  0.000000  6.809166   0.0
# olahraga     0.000000  0.000000  0.000000  0.000000   0.0
# penting      0.000000  0.000000  0.000000  6.809166   0.0
# periksa      0.000000  6.809166  0.000000  0.000000   0.0
# pola         0.000000  0.000000  0.000000  0.000000   0.0
# putih        0.000000  0.000000  0.000000  6.809166   0.0
# rumah        0.000000  6.809166  0.000000  0.000000   0.0
# rutin        0.000000  0.000000  0.000000  0.000000   0.0
# sakit        0.000000  3.672170  0.000000  0.000000   0.0
# sebab        0.000000  0.000000  0.000000  0.000000   0.0
# sedia        0.000000  6.809166  0.000000  0.000000   0.0
# sehat        3.672170  0.000000  0.000000  0.000000   0.0
# seluruh      0.000000  0.000000  0.000000  0.000000   0.0
# stamina      0.000000  0.000000  0.000000  0.000000   0.0
# tidur        0.000000  0.000000  0.000000  0.000000   0.0
# tingkat      0.000000  0.000000  0.000000  0.000000   0.0
# tubuh        0.000000  0.000000  0.000000  2.282594   0.0
# Ranking cosine similarity:
#   dokumen   Sum(Q*D)       |Q|       |D|  cosine_similarity
# 2      D3  10.481336  3.572664  6.071540           0.483198
# 0      D1   5.954764  3.572664  5.956007           0.279845
# 1      D2   2.282594  3.572664  6.324602           0.101019
# 3      D4   2.282594  3.572664  6.324602           0.101019
# 4      D5   0.000000  3.572664  6.324602           0.000000

# %%
print(f"query : ",query)
# Display top 3 ranked documents
top_3 = df_cosine.head(3)


# Tampilkan detail dokumen asli untuk top 3
print("\nDokumen Asli Top 3:")
for idx, row in top_3.iterrows():
    doc_num = int(row['dokumen'][1]) - 1  
    print(f"{row['dokumen']}: {docs[doc_num]}")
    print(f"   Cosine Similarity: {row['cosine_similarity']:.6f}\n")
# Out:
# query :  pola hidup sehat untuk menjaga jantung
#
# Dokumen Asli Top 3:
# D3: tidur yang cukup membantu menjaga kesehatan tubuh secara keseluruhan
#    Cosine Similarity: 0.483198
#
# D1: olahraga rutin dapat meningkatkan kesehatan jantung dan stamina tubuh
#    Cosine Similarity: 0.279845
#
# D2: konsumsi makanan berlemak berlebihan dapat menyebabkan penyakit jantung
#    Cosine Similarity: 0.101019

# %% [markdown]
# ## NOTESS
#
# [] Pelajari bagian Hitung Jarak Tiap Dokumen ke bawah karena Sing Ngerti
